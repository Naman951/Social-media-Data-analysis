# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Social Media ')

# %%
df.head(5)
# Out:
#     Platform      Owner                 Primary Usage           Country  \
# 0   WhatsApp       Meta                     Messaging       Switzerland
# 1     WeChat    Tencent    Messaging and social media        Madagascar
# 2   Snapchat  Snap Inc.          Multimedia messaging  Pitcairn Islands
# 3  Instagram       Meta       Photo and video sharing       Timor-Leste
# 4    Threads       Meta  Text-based social networking           Bermuda
#
#    Daily Time Spent (min) Verified Account Date Joined
# 0                  113.94              Yes  2019-03-03
# 1                   49.63              Yes  2023-09-21
# 2                   29.01              Yes  2020-12-13
# 3                  295.43              Yes  2019-04-21
# 4                   71.78               No  2015-07-14

# %%
df.isnull().sum()
# Out:
# Platform                  0
# Owner                     0
# Primary Usage             0
# Country                   0
# Daily Time Spent (min)    0
# Verified Account          0
# Date Joined               0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.describe()
# Out:
#        Daily Time Spent (min)
# count            10000.000000
# mean               152.211145
# std                 85.142750
# min                  5.020000
# 25%                 78.920000
# 50%                152.735000
# 75%                225.642500
# max                300.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Platform                10000 non-null  object
#  1   Owner                   10000 non-null  object
#  2   Primary Usage           10000 non-null  object
#  3   Country                 10000 non-null  object
#  4   Daily Time Spent (min)  10000 non-null  float64
#  5   Verified Account        10000 non-null  object
#  6   Date Joined             10000 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 547.0+ KB

# %%
df.head()
# Out:
#     Platform      Owner                 Primary Usage           Country  \
# 0   WhatsApp       Meta                     Messaging       Switzerland
# 1     WeChat    Tencent    Messaging and social media        Madagascar
# 2   Snapchat  Snap Inc.          Multimedia messaging  Pitcairn Islands
# 3  Instagram       Meta       Photo and video sharing       Timor-Leste
# 4    Threads       Meta  Text-based social networking           Bermuda
#
#    Daily Time Spent (min) Verified Account Date Joined
# 0                  113.94              Yes  2019-03-03
# 1                   49.63              Yes  2023-09-21
# 2                   29.01              Yes  2020-12-13
# 3                  295.43              Yes  2019-04-21
# 4                   71.78               No  2015-07-14

# %%
df['Verified Account'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Verified Account'] = df['Verified Account'].replace({'Yes': 1, 'No': 0})
# Out:
# <ipython-input-96-0a9a271764ae>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Verified Account'] = df['Verified Account'].replace({'Yes': 1, 'No': 0})

# %%
df['Verified Account'].inplace=True

# %%
df.drop('Owner', axis=1, inplace=True)

# %%
df
# Out:
#        Platform                      Primary Usage  \
# 0      WhatsApp                          Messaging
# 1        WeChat         Messaging and social media
# 2      Snapchat               Multimedia messaging
# 3     Instagram            Photo and video sharing
# 4       Threads       Text-based social networking
# ...         ...                                ...
# 9995  Pinterest   Visual discovery and bookmarking
# 9996     Reddit  Discussion forums and communities
# 9997      Quora              Q&A knowledge sharing
# 9998      Quora              Q&A knowledge sharing
# 9999     Reddit  Discussion forums and communities
#
#                                Country  Daily Time Spent (min)  \
# 0                          Switzerland                  113.94
# 1                           Madagascar                   49.63
# 2                     Pitcairn Islands                   29.01
# 3                          Timor-Leste                  295.43
# ...

# %%
df['Verified Account'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['skyblue', 'pink'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Platform'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %%
df['Primary Usage'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# categorical column

# %%
sns.countplot(df['Platform' ])
# Out:
# <Axes: xlabel='count', ylabel='Platform'>

# %%
sns.countplot(df['Primary Usage' ])
# Out:
# <Axes: xlabel='count', ylabel='Primary Usage'>

# %% [markdown]
# Numerical column

# %%
plt.hist(df['Daily Time Spent (min)'], bins = 200)
# Out:
# (array([51., 40., 52., 45., 59., 63., 58., 43., 47., 45., 57., 47., 55.,
#         56., 43., 51., 53., 58., 60., 49., 45., 34., 32., 54., 50., 62.,
#         53., 40., 46., 43., 65., 44., 60., 46., 63., 60., 43., 48., 51.,
#         42., 39., 68., 42., 62., 41., 31., 52., 38., 53., 56., 54., 53.,
#         45., 45., 53., 53., 51., 66., 43., 55., 55., 59., 50., 41., 35.,
#         45., 46., 46., 45., 48., 56., 54., 50., 62., 56., 54., 45., 66.,
#         44., 49., 55., 58., 51., 51., 59., 51., 44., 48., 38., 37., 35.,
#         47., 38., 51., 59., 45., 62., 59., 48., 39., 55., 56., 43., 58.,
#         57., 54., 51., 46., 46., 46., 51., 44., 56., 50., 53., 52., 54.,
#         68., 52., 64., 40., 42., 54., 66., 46., 39., 46., 49., 44., 56.,
#         43., 45., 44., 44., 53., 61., 52., 41., 44., 48., 50., 61., 48.,
#         59., 43., 40., 63., 55., 47., 45., 52., 57., 44., 45., 47., 36.,
#         48., 38., 66., 50., 47., 41., 56., 40., 52., 68., 35., 68., 61.,
# ...

# %%
sns.displot(df['Daily Time Spent (min)'])

# %%
sns.boxplot(df['Daily Time Spent (min)'])
# Out:
# <Axes: ylabel='Daily Time Spent (min)'>

# %% [markdown]
# multivarient analysis

# %% [markdown]
# scatterplot(numerical-numerical)
# 1.Scattrplot
# 2.Bar plot(num.-cat)
# 3.box plot( " )
# 4.distplot( " )

# %%
sns.kdeplot(df['Daily Time Spent (min)'])
# Out:
# <Axes: xlabel='Daily Time Spent (min)', ylabel='Density'>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df[['Daily Time Spent (min)']])
# Out:
# MinMaxScaler()

# %% [markdown]
# label encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()

# %%
df['Platform_Encoded'] = label_encoder.fit_transform(df['Platform'])

# %%
df
# Out:
#        Platform                      Primary Usage  \
# 0      WhatsApp                          Messaging
# 1        WeChat         Messaging and social media
# 2      Snapchat               Multimedia messaging
# 3     Instagram            Photo and video sharing
# 4       Threads       Text-based social networking
# ...         ...                                ...
# 9995  Pinterest   Visual discovery and bookmarking
# 9996     Reddit  Discussion forums and communities
# 9997      Quora              Q&A knowledge sharing
# 9998      Quora              Q&A knowledge sharing
# 9999     Reddit  Discussion forums and communities
#
#                                Country  Daily Time Spent (min)  \
# 0                          Switzerland                  113.94
# 1                           Madagascar                   49.63
# 2                     Pitcairn Islands                   29.01
# 3                          Timor-Leste                  295.43
# ...
